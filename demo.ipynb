# %%
import sys
from yolo import YOLO, detect_video
from PIL import Image
# Out:
# Using TensorFlow backend.
# /home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# the input file path
input_path = "/data/dataset/relaxing_highway_traffic_5992.mp4"
output_path = "output_traffic.mp4"

FLAGS = dict()
FLAGS = {"model_path": "model_data/yolo_tiny.h5",
         "anchors_path": "model_data/tiny_yolo_anchors.txt",
         "classes_path": "model_data/coco_classes.txt"}

detect_video(YOLO(FLAGS), input_path, output_path)
# Out:
# model_data/yolo_tiny.h5 model, anchors, and classes loaded.
# !!! TYPE: <class 'str'> <class 'int'> <class 'float'> <class 'tuple'>
# (416, 416, 3)
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#
# ~/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#
# ~/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#
# InternalError: Blas SGEMM launch failed : m=169, n=256, k=1024
# 	 [[Node: conv2d_8/convolution = Conv2D[T=DT_FLOAT, _class=["loc:@batch_normalization_8/cond/FusedBatchNorm/Switch"], data_format="NHWC", dilations=[1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](leaky_re_lu_7/LeakyRelu, conv2d_8/kernel/read)]]
# 	 [[Node: boolean_mask_76/GatherV2/_1115 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_4208_boolean_mask_76/GatherV2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-fd40e8f6bbb2> in <module>()
#       8          "classes_path": "model_data/coco_classes.txt"}
#       9
# ---> 10 detect_video(YOLO(FLAGS), input_path, output_path)
#
# ~/workspace/keras-yolo3/yolo.py in detect_video(yolo, video_path, output_path)
#     193         start_time = datetime.datetime.now()
#     194         image = Image.fromarray(frame)
# --> 195         image = yolo.detect_image(image)
#     196         result = np.asarray(image)
#     197         curr_time = timer()
#
# ~/workspace/keras-yolo3/yolo.py in detect_image(self, image)
#     122                 self.yolo_model.input: image_data,
#     123                 self.input_image_shape: [image.size[1], image.size[0]],
# --> 124                 K.learning_phase(): 0
#     125             })
#     126
#
# ~/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1289         except KeyError:
#    1290           pass
# -> 1291       raise type(e)(node_def, op, message)
#    1292
#    1293   def _extend_graph(self):
#
# InternalError: Blas SGEMM launch failed : m=169, n=256, k=1024
# 	 [[Node: conv2d_8/convolution = Conv2D[T=DT_FLOAT, _class=["loc:@batch_normalization_8/cond/FusedBatchNorm/Switch"], data_format="NHWC", dilations=[1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](leaky_re_lu_7/LeakyRelu, conv2d_8/kernel/read)]]
# 	 [[Node: boolean_mask_76/GatherV2/_1115 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_4208_boolean_mask_76/GatherV2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
#
# Caused by op 'conv2d_8/convolution', defined at:
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/asyncio/base_events.py", line 345, in run_forever
#     self._run_once()
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/asyncio/base_events.py", line 1312, in _run_once
#     handle._run()
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/asyncio/events.py", line 125, in _run
#     self._callback(*self._args)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2907, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-fd40e8f6bbb2>", line 10, in <module>
#     detect_video(YOLO(FLAGS), input_path, output_path)
#   File "/home/weizhuozhang/workspace/keras-yolo3/yolo.py", line 45, in __init__
#     self.boxes, self.scores, self.classes = self.generate()
#   File "/home/weizhuozhang/workspace/keras-yolo3/yolo.py", line 70, in generate
#     self.yolo_model = load_model(model_path, compile=False)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/keras/engine/saving.py", line 260, in load_model
#     model = model_from_config(model_config, custom_objects=custom_objects)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/keras/engine/saving.py", line 334, in model_from_config
#     return deserialize(config, custom_objects=custom_objects)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/keras/layers/__init__.py", line 55, in deserialize
#     printable_module_name='layer')
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/keras/utils/generic_utils.py", line 145, in deserialize_keras_object
#     list(custom_objects.items())))
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/keras/engine/network.py", line 1027, in from_config
#     process_node(layer, node_data)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/keras/engine/network.py", line 986, in process_node
#     layer(unpack_singleton(input_tensors), **kwargs)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/keras/engine/base_layer.py", line 457, in __call__
#     output = self.call(inputs, **kwargs)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/keras/layers/convolutional.py", line 168, in call
#     dilation_rate=self.dilation_rate)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py", line 3565, in conv2d
#     data_format=tf_data_format)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/ops/nn_ops.py", line 780, in convolution
#     return op(input, filter)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/ops/nn_ops.py", line 868, in __call__
#     return self.conv_op(inp, filter)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/ops/nn_ops.py", line 520, in __call__
#     return self.call(inp, filter)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/ops/nn_ops.py", line 204, in __call__
#     name=self.name)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/ops/gen_nn_ops.py", line 956, in conv2d
#     data_format=data_format, dilations=dilations, name=name)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py", line 454, in new_func
#     return func(*args, **kwargs)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 3155, in create_op
#     op_def=op_def)
#   File "/home/weizhuozhang/anaconda3/envs/keras_yolov3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1717, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# InternalError (see above for traceback): Blas SGEMM launch failed : m=169, n=256, k=1024
# 	 [[Node: conv2d_8/convolution = Conv2D[T=DT_FLOAT, _class=["loc:@batch_normalization_8/cond/FusedBatchNorm/Switch"], data_format="NHWC", dilations=[1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](leaky_re_lu_7/LeakyRelu, conv2d_8/kernel/read)]]
# 	 [[Node: boolean_mask_76/GatherV2/_1115 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device_incarnation=1, tensor_name="edge_4208_boolean_mask_76/GatherV2", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:CPU:0"]()]]
